# %% [markdown]
# <div style="font-family: Arial, Helvetica, sans-serif;">
#     <div style="display: flex;padding-top: 20px">
#         <div><strong>Course:</strong> Programming for Data Science</div>
#     </div>
#     <div style="display: flex;padding-top: 20px">
#         <div style="padding-right: 10px;"><strong>Class:</strong> 22KHDL</div>
#         <div></div>
#     </div>
#     <div style="display: flex;padding-top: 20px">
#         <div style="padding-right: 10px;"><strong>Group:</strong></div>
#     </div>
#     <div>
#         <div style="display: flex;padding-top: 20px">
#             <div style="padding-right: 10px;"><strong>Members:</strong></div>
#             <div></div>
#         </div>
#         <table style="font-size: 15px; display:flex;padding-top: 20px">
#             <tr>
#                 <th>No.</th>
#                 <th>Student ID</th>
#                 <th>Name</th>
#             </tr>
#             <tr>
#                 <td>1</td>
#                 <td>22127008</td>
#                 <td style="text-align:left;">Đặng Châu Anh</td>
#             </tr>
#             <tr>
#                 <td>2</td>
#                 <td>22127014</td>
#                 <td style="text-align:left;">Nguyễn Kim Anh</td>
#             </tr>
#             <tr>
#                 <td>4</td>
#                 <td>22127170</td>
#                 <td style="text-align:left;">Trần Dịu Huyền</td>
#             </tr>
#         </table>
#     </div>
#     <div style="font-size: 25px ;font-weight: 800; text-align: center;padding-top: 20px;">FINAL PROJECT</div>
#     <div style="font-size: 20px ;font-weight: 800; text-align: center;padding-top: 20px;">COVID - 19 ANALYSIS - DATA COLLECTION</div>
# </div>

# %% [markdown]
# # **Table of Contents**
#
# - [**Introduction**](#introduction)
#     - [Project objectives](#objectives)
#     - [Project purpose](#purposes)
#     - [Data source details](#source)
#
# - [**Import packages**](#import)
#
# - [**Load datasets**](#load)

# %% [markdown]
# <a id="introduction"></a>
# # **I. Introduction**
# <a id="objectives"></a>
# ## **1. Project objectives:**
# <a id="purposes"></a>
# ## **2. Project purposes:**
# <a id="source"></a>
# ## **3. Data source details:**

# %% [markdown]
# <a id="import"></a>
# # **II. Import packages**

# %%
import pandas as pd

# %% [markdown]
# <a id="load"></a>
# # **III. Load datasets**

# %% [markdown]
# Datasets stored in the `./data` directory
# Datasets contain:
# - `full_grouped.csv` - Day to day country wise number of cases (Does not have County/State/Province level data)
# - `day_wise` - Day to day data

# %% [markdown]
# - Worldwide data - `worldometer_data.csv`:
#     + 30 January 2020
#     + Scrape from https://www.worldometers.info/

# %%
# worldometer_data.csv
worldometer_data = pd.read_csv("./data/worldometer_data.csv")
worldometer_data.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %% [markdown]
# - Read `country_wise_latest.csv` dataset - Latest country level no. of cases

# %%
country_wise_lastest = pd.read_csv(r"./data/country_wise_latest.csv")
country_wise_lastest
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# - `covid_19_clean_complete.csv` - Day to day country wise number of cases (Has County/State/Province level data)

# %%
clean_complete = pd.read_csv(r"./data/covid_19_clean_complete.csv")
clean_complete
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...
